# %%
def similaridade_tipoimovel(imovel,utilizador):
    if imovel=="Apartamento" and utilizador=="Moradia":
        return 0
    if imovel=="Apartamento" and utilizador=="Apartamento":
        return 1
    if imovel=="Moradia" and utilizador=="Apartamento":
        return 0
    if imovel=="Moradia" and utilizador=="Moradia":
        return 1
    else:
        return 0
    
def similaridade_local(imovel,utilizador):
    if imovel=="Vila Real" and utilizador=="Vila Real":
        return 1
    if imovel=="Vila Real" and utilizador=="Porto":
        return 0.3
    if imovel=="Vila Real" and utilizador=="Lisboa":
        return 0.2
    if imovel=="Vila Real" and utilizador=="Chaves":
        return 0.8
    if imovel=="Vila Real" and utilizador=="Leiria":
        return 0.6
    if imovel=="Vila Real" and utilizador=="Portalegre":
        return 0.5
    if imovel=="Vila Real" and utilizador=="Braga":
        return 0.4
    if imovel=="Vila Real" and utilizador=="Aveiro":
        return 0.4
    if imovel=="Vila Real" and utilizador=="Santarem":
        return 0.7
    if imovel=="Porto" and utilizador=="Vila Real":
        return 0.7
    if imovel=="Porto" and utilizador=="Porto":
        return 1
    if imovel=="Porto" and utilizador=="Lisboa":
        return 0.8
    if imovel=="Porto" and utilizador=="Chaves":
        return 0.2
    if imovel=="Porto" and utilizador=="Leiria":
        return 0.4
    if imovel=="Porto" and utilizador=="Portalegre":
        return 0.5
    if imovel=="Porto" and utilizador=="Santarem":
        return 0.4
    if imovel=="Porto" and utilizador=="Braga":
        return 0.6
    if imovel=="Porto" and utilizador=="Aveiro":
        return 0.7
    if imovel=="Lisboa" and utilizador=="Vila Real":
        return 0.2
    if imovel=="Lisboa" and utilizador=="Porto":
        return 0.8
    if imovel=="Lisboa" and utilizador=="Lisboa":
        return 1
    if imovel=="Lisboa" and utilizador=="Chaves":
        return 0.2
    if imovel=="Lisboa" and utilizador=="Leiria":
        return 0.6
    if imovel=="Lisboa" and utilizador=="Portalegre":
        return 0.7
    if imovel=="Lisboa" and utilizador=="Braga":
        return 0.4
    if imovel=="Lisboa" and utilizador=="Aveiro":
        return 0.5
    if imovel=="Lisboa" and utilizador=="Santarem":
        return 0.4
    if imovel=="Chaves" and utilizador=="Vila Real":
        return 0.8
    if imovel=="Chaves" and utilizador=="Porto":
        return 0.3
    if imovel=="Chaves" and utilizador=="Lisboa":
        return 0.2
    if imovel=="Chaves" and utilizador=="Chaves":
        return 1
    if imovel=="Chaves" and utilizador=="Leiria":
        return 0.6
    if imovel=="Chaves" and utilizador=="Portalegre":
        return 0.5
    if imovel=="Chaves" and utilizador=="Braga":
        return 0.4
    if imovel=="Chaves" and utilizador=="Aveiro":
        return 0.3
    if imovel=="Chaves" and utilizador=="Santarem":
        return 0.4
    if imovel=="Leiria" and utilizador=="Vila Real":
        return 0.4
    if imovel=="Leiria" and utilizador=="Porto":
        return 0.6
    if imovel=="Leiria" and utilizador=="Lisboa":
        return 0.4
    if imovel=="Leiria" and utilizador=="Chaves":
        return 0.3
    if imovel=="Leiria" and utilizador=="Leiria":
        return 1
    if imovel=="Leiria" and utilizador=="Portalegre":
        return 0.7
    if imovel=="Leiria" and utilizador=="Braga":
        return 0.5
    if imovel=="Leiria" and utilizador=="Aveiro":
        return 0.4
    if imovel=="Leiria" and utilizador=="Santarem":
        return 0.7
    if imovel=="Portalegre" and utilizador=="Vila Real":
        return 0.5
    if imovel=="Portalegre" and utilizador=="Porto":
        return 0.3
    if imovel=="Portalegre" and utilizador=="Lisboa":
        return 0.4
    if imovel=="Portalegre" and utilizador=="Chaves":
        return 0.7
    if imovel=="Portalegre" and utilizador=="Leiria":
        return 0.8
    if imovel=="Portalegre" and utilizador=="Portalegre":
        return 1
    if imovel=="Portalegre" and utilizador=="Braga":
        return 0.4
    if imovel=="Portalegre" and utilizador=="Aveiro":
        return 0.4
    if imovel=="Portalegre" and utilizador=="Santarem":
        return 0.6
    if imovel=="Santarem" and utilizador=="Vila Real":
        return 0.7
    if imovel=="Santarem" and utilizador=="Porto":
        return 0.4
    if imovel=="Santarem" and utilizador=="Lisboa":
        return 0.6
    if imovel=="Santarem" and utilizador=="Chaves":
        return 0.4
    if imovel=="Santarem" and utilizador=="Leiria":
        return 0.6
    if imovel=="Santarem" and utilizador=="Portalegre":
        return 0.7
    if imovel=="Santarem" and utilizador=="Santarem":
        return 1
    if imovel=="Santarem" and utilizador=="Braga":
        return 0.5
    if imovel=="Santarem" and utilizador=="Aveiro":
        return 0.4
    if imovel=="Braga" and utilizador=="Vila Real":
        return 0.5
    if imovel=="Braga" and utilizador=="Porto":
        return 0.6
    if imovel=="Braga" and utilizador=="Lisboa":
        return 0.4
    if imovel=="Braga" and utilizador=="Chaves":
        return 0.4
    if imovel=="Braga" and utilizador=="Leiria":
        return 0.5
    if imovel=="Braga" and utilizador=="Portalegre":
        return 0.4
    if imovel=="Braga" and utilizador=="Santarem":
        return 0.5
    if imovel=="Braga" and utilizador=="Braga":
        return 1
    if imovel=="Braga" and utilizador=="Aveiro":
        return 0.5
    if imovel=="Aveiro" and utilizador=="Vila Real":
        return 0.4
    if imovel=="Aveiro" and utilizador=="Porto":
        return 0.7
    if imovel=="Aveiro" and utilizador=="Lisboa":
        return 0.5
    if imovel=="Aveiro" and utilizador=="Chaves":
        return 0.3
    if imovel=="Aveiro" and utilizador=="Leiria":
        return 0.4
    if imovel=="Aveiro" and utilizador=="Portalegre":
        return 0.4
    if imovel=="Aveiro" and utilizador=="Santarem":
        return 0.4
    if imovel=="Aveiro" and utilizador=="Braga":
        return 0.5
    if imovel=="Aveiro" and utilizador=="Aveiro":
        return 1
    if utilizador=="Vila Real" and imovel=="Porto":
        return 0.3
    if utilizador=="Vila Real" and imovel=="Lisboa":
        return 0.2
    if utilizador=="Vila Real" and imovel=="Chaves":
        return 0.8
    if utilizador=="Vila Real" and imovel=="Leiria":
        return 0.6
    if utilizador=="Vila Real" and imovel=="Portalegre":
        return 0.5
    if utilizador=="Vila Real" and imovel=="Braga":
        return 0.4
    if utilizador=="Vila Real" and imovel=="Aveiro":
        return 0.4
    if utilizador=="Vila Real" and imovel=="Santarem":
        return 0.7
    if utilizador=="Porto" and imovel=="Vila Real":
        return 0.7
    if utilizador=="Porto" and imovel=="Lisboa":
        return 0.8
    if utilizador=="Porto" and imovel=="Chaves":
        return 0.8
    if utilizador=="Porto" and imovel=="Leiria":
        return 0.4
    if utilizador=="Porto" and imovel=="Portalegre":
        return 0.5
    if utilizador=="Porto" and imovel=="Braga":
        return 0.6
    if utilizador=="Porto" and imovel=="Aveiro":
        return 0.7
    if utilizador=="Porto" and imovel=="Santarem":
        return 0.7
    if utilizador=="Lisboa" and imovel=="Vila Real":
        return 0.2
    if utilizador=="Lisboa" and imovel=="Porto":
        return 0.8
    if utilizador=="Lisboa" and imovel=="Chaves":
        return 0.2
    if utilizador=="Lisboa" and imovel=="Leiria":
        return 0.6
    if utilizador=="Lisboa" and imovel=="Portalegre":
        return 0.7
    if utilizador=="Lisboa" and imovel=="Braga":
        return 0.4
    if utilizador=="Lisboa" and imovel=="Aveiro":
        return 0.5
    if utilizador=="Lisboa" and imovel=="Santarem":
        return 0.4
    if utilizador=="Chaves" and imovel=="Vila Real":
        return 0.8
    if utilizador=="Chaves" and imovel=="Porto":
        return 0.3
    if utilizador=="Chaves" and imovel=="Lisboa":
        return 0.2
    if utilizador=="Chaves" and imovel=="Leiria":
        return 0.6
    if utilizador=="Chaves" and imovel=="Portalegre":
        return 0.5
    if utilizador=="Chaves" and imovel=="Braga":
        return 0.4
    if utilizador=="Chaves" and imovel=="Aveiro":
        return 0.3
    if utilizador=="Chaves" and imovel=="Santarem":
        return 0.4
    if utilizador=="Leiria" and imovel=="Vila Real":
        return 0.6
    if utilizador=="Leiria" and imovel=="Porto":
        return 0.6
    if utilizador=="Leiria" and imovel=="Lisboa":
        return 0.4
    if utilizador=="Leiria" and imovel=="Chaves":
        return 0.6
    if utilizador=="Leiria" and imovel=="Portalegre":
        return 0.7
    if utilizador=="Leiria" and imovel=="Braga":
        return 0.5
    if utilizador=="Leiria" and imovel=="Aveiro":
        return 0.4
    if utilizador=="Leiria" and imovel=="Santarem":
        return 0.7
    if utilizador=="Portalegre" and imovel=="Vila Real":
        return 0.5
    if utilizador=="Portalegre" and imovel=="Porto":
        return 0.3
    if utilizador=="Portalegre" and imovel=="Lisboa":
        return 0.4
    if utilizador=="Portalegre" and imovel=="Chaves":
        return 0.7
    if utilizador=="Portalegre" and imovel=="Leiria":
        return 0.8
    if utilizador=="Portalegre" and imovel=="Braga":
        return 0.4
    if utilizador=="Portalegre" and imovel=="Aveiro":
        return 0.4
    if utilizador=="Portalegre" and imovel=="Santarem":
        return 0.6
    if utilizador=="Santarem" and imovel=="Vila Real":
        return 0.7
    if utilizador=="Santarem" and imovel=="Porto":
        return 0.4
    if utilizador=="Santarem" and imovel=="Lisboa":
        return 0.6
    if utilizador=="Santarem" and imovel=="Chaves":
        return 0.4
    if utilizador=="Santarem" and imovel=="Leiria":
        return 0.6
    if utilizador=="Santarem" and imovel=="Portalegre":
        return 0.7
    if utilizador=="Santarem" and imovel=="Braga":
        return 0.5
    if utilizador=="Santarem" and imovel=="Aveiro":
        return 0.4
    if utilizador=="Braga" and imovel=="Vila Real":
        return 0.5
    if utilizador=="Braga" and imovel=="Porto":
        return 0.6
    if utilizador=="Braga" and imovel=="Lisboa":
        return 0.4
    if utilizador=="Braga" and imovel=="Chaves":
        return 0.4
    if utilizador=="Braga" and imovel=="Leiria":
        return 0.5
    if utilizador=="Braga" and imovel=="Portalegre":
        return 0.4
    if utilizador=="Braga" and imovel=="Santarem":
        return 0.5
    if utilizador=="Braga" and imovel=="Aveiro":
        return 0.5
    if utilizador=="Aveiro" and imovel=="Vila Real":
        return 0.4
    if utilizador=="Aveiro" and imovel=="Porto":
        return 0.7
    if utilizador=="Aveiro" and imovel=="Lisboa":
        return 0.5
    if utilizador=="Aveiro" and imovel=="Chaves":
        return 0.3
    if utilizador=="Aveiro" and imovel=="Leiria":
        return 0.4
    if utilizador=="Aveiro" and imovel=="Portalegre":
        return 0.4
    if utilizador=="Aveiro" and imovel=="Santarem":
        return 0.4
    if utilizador=="Aveiro" and imovel=="Braga":
        return 0.5
    else:
        return 0
    
def similaridade_quartos(imovel,utilizador):
    if imovel==5 and utilizador==5:
        return 1
    if imovel==5 and utilizador==4:
        return 0.8
    if imovel==5 and utilizador==3:
        return 0.6
    if imovel==5 and utilizador==2:
        return 0.4
    if imovel==5 and utilizador==1:
        return 0.2
    if imovel==5 and utilizador==0:
        return 0
    if imovel==4 and utilizador==5:
        return 0.8
    if imovel==4 and utilizador==4:
        return 1
    if imovel==4 and utilizador==3:
        return 0.8
    if imovel==4 and utilizador==2:
        return 0.5
    if imovel==4 and utilizador==1:
        return 0.2
    if imovel==4 and utilizador==0:
        return 0
    if imovel==3 and utilizador==5:
        return 0.4
    if imovel==3 and utilizador==4:
        return 0.8
    if imovel==3 and utilizador==3:
        return 1
    if imovel==3 and utilizador==2:
        return 0.8
    if imovel==3 and utilizador==1:
        return 0.4
    if imovel==3 and utilizador==0:
        return 0
    if imovel==2 and utilizador==5:
        return 0.2
    if imovel==2 and utilizador==4:
        return 0.4
    if imovel==2 and utilizador==3:
        return 0.8
    if imovel==2 and utilizador==2:
        return 1
    if imovel==2 and utilizador==1:
        return 0.8
    if imovel==2 and utilizador==0:
        return 0.4
    if imovel==1 and utilizador==5:
        return 0.2
    if imovel==1 and utilizador==4:
        return 0.4
    if imovel==1 and utilizador==3:
        return 0.6
    if imovel==1 and utilizador==2:
        return 0.8
    if imovel==1 and utilizador==1:
        return 1
    if imovel==1 and utilizador==0:
        return 0.8
    if imovel==0 and utilizador==5:
        return 0
    if imovel==0 and utilizador==4:
        return 0.2
    if imovel==0 and utilizador==3:
        return 0.4
    if imovel==0 and utilizador==2:
        return 0.6
    if imovel==0 and utilizador==1:
        return 0.8
    if imovel==0 and utilizador==0:
        return 1
    if utilizador==5 and imovel==4:
        return 0.8
    if utilizador==5 and imovel==3:
        return 0.6
    if utilizador==5 and imovel==2:
        return 0.4
    if utilizador==5 and imovel==1:
        return 0.2
    if utilizador==5 and imovel==0:
        return 0
    if utilizador==4 and imovel==5:
        return 0.8
    if utilizador==4 and imovel==3:
        return 0.8
    if utilizador==4 and imovel==2:
        return 0.5
    if utilizador==4 and imovel==1:
        return 0.2
    if utilizador==4 and imovel==0:
        return 0
    if utilizador==3 and imovel==5:
        return 0.4
    if utilizador==3 and imovel==4:
        return 0.8
    if utilizador==3 and imovel==2:
        return 0.8
    if utilizador==3 and imovel==1:
        return 0.4
    if utilizador==3 and imovel==0:
        return 0
    if utilizador==2 and imovel==5:
        return 0.2
    if utilizador==2 and imovel==4:
        return 0.4
    if utilizador==2 and imovel==3:
        return 0.8
    if utilizador==2 and imovel==1:
        return 0.8
    if utilizador==2 and imovel==0:
        return 0.4
    if utilizador==1 and imovel==5:
        return 0.2
    if utilizador==1 and imovel==4:
        return 0.4
    if utilizador==1 and imovel==3:
        return 0.6
    if utilizador==1 and imovel==2:
        return 0.8
    if utilizador==1 and imovel==0:
        return 0.8
    if utilizador==0 and imovel==5:
        return 0
    if utilizador==0 and imovel==4:
        return 0.2
    if utilizador==0 and imovel==3:
        return 0.4
    if utilizador==0 and imovel==2:
        return 0.6
    if utilizador==0 and imovel==1:
        return 0.8
    else:
        return 0
    
def similaridade_estado(imovel,utilizador):
    if imovel=="Novo" and utilizador=="Novo":
        return 1
    if imovel=="Novo" and utilizador=="Renovado": 
        return 0.5
    if imovel=="Novo" and utilizador=="Usado": 
        return 0
    if imovel=="Renovado" and utilizador=="Renovado":
        return 1
    if imovel=="Renovado" and utilizador=="Novo": 
        return 0.5
    if imovel=="Renovado" and utilizador=="Usado":
        return 0
    if imovel=="Usado" and utilizador=="Usado":
        return 1
    if imovel=="Usado" and utilizador=="Novo": 
        return 0
    if imovel=="Usado" and utilizador=="Renovado": 
        return 0
    else:
        return 0
imovel_utilizador=[]
imovel_utilizador.append(input("Introduza o tipo de imovel:\n"))
imovel_utilizador.append(input("Introduza o local:\n"))
imovel_utilizador.append(input("Introduza o nº de quartos:\n"))
imovel_utilizador.append(input("Introduza o estado:\n"))
ficheiro=open("imoveis.txt","r")
imovel_todos=ficheiro.read().split("\n")
ficheiro.close()
lista=[]
for imovel in imovel_todos:
    detalhes=imovel.split(";")
    detalhes[2]=str(detalhes[2])
    detalhes[4]=str(detalhes[4])
    lista.append(detalhes)
peso=[0.3, 0.4, 0.1, 0.2 ] 
melhor_similaridade=0
similaridade=0
                            
for imovel in lista:
    similaridade=similaridade_tipoimovel(imovel[0],imovel_utilizador[0])*peso[0]+similaridade_local(imovel[1],imovel_utilizador[1])*peso[1]+similaridade_quartos(imovel[2],imovel_utilizador[2])*peso[2]+similaridade_estado(imovel[3],imovel_utilizador[3])*peso[3]
    if similaridade > melhor_similaridade:
        melhor_similaridade=similaridade
        imovel_escolhido=imovel

print("O imóvel pedido é:\n", imovel_utilizador)
print("O imóvel mais parecido com o pedido é:\n", imovel_escolhido)
imovel_utilizador.append(imovel_escolhido[4])
strimovel="\n"+";".join(imovel_utilizador) 
ficheiro=open("imoveis.txt","a")
ficheiro.write(strimovel)
ficheiro.close()
# Out:
# Introduza o tipo de imovel:
# Moradia
# Introduza o local:
# Santarem
# Introduza o nº de quartos:
# 1
# Introduza o estado:
# Novo
# O imóvel pedido é:
#  ['Moradia', 'Santarem', '1', 'Novo']
# O imóvel mais parecido com o pedido é:
#  ['Moradia', 'Leiria', '3', 'Novo', '159000']
